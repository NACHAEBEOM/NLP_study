# %%
import sys
import tensorflow as tf
import numpy as np
import os
import pandas as pd

from sklearn.model_selection import train_test_split

import json

# %%
## 미리 Global 변수를 지정하자. 파일 명, 파일 위치, 디렉토리 등이 있다.

DATA_IN_PATH = './data/'
DATA_OUT_PATH = './output/'

TRAIN_Q1_DATA_FILE = 'train_q1.npy'
TRAIN_Q2_DATA_FILE = 'train_q2.npy'
TRAIN_LABEL_DATA_FILE = 'train_label.npy'
DATA_CONFIGS = 'data_configs.json'

## 학습에 필요한 파라메터들에 대해서 지정하는 부분이다.

BATCH_SIZE = 16
EPOCH = 2
HIDDEN = 64
BUFFER_SIZE = 10000

NUM_LAYERS = 3
DROPOUT_RATIO = 0.3

TEST_SPLIT = 0.1
RNG_SEED = 13371447
EMBEDDING_DIM = 128
MAX_SEQ_LEN = 31

# %%
q1_data = np.load(open(DATA_IN_PATH + TRAIN_Q1_DATA_FILE, 'rb'))
q2_data = np.load(open(DATA_IN_PATH + TRAIN_Q2_DATA_FILE, 'rb'))
labels = np.load(open(DATA_IN_PATH + TRAIN_LABEL_DATA_FILE, 'rb'))
prepro_configs = None

with open(DATA_IN_PATH + DATA_CONFIGS, 'r') as f:
    prepro_configs = json.load(f)

# %%
VOCAB_SIZE = prepro_configs['vocab_size']

# %%
q1_data_len = np.array([min(len(x), MAX_SEQ_LEN) for x in q1_data])
q2_data_len = np.array([min(len(x), MAX_SEQ_LEN) for x in q2_data])

# %%
X = np.stack((q1_data, q2_data), axis=1)
y = labels
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=TEST_SPLIT, random_state=RNG_SEED)

train_Q1 = train_X[:,0]
train_Q2 = train_X[:,1]
test_Q1 = test_X[:,0]
test_Q2 = test_X[:,1]

# %%
def rearrange(base, hypothesis, labels):
    features = {"base": base, "hypothesis": hypothesis}
    return features, labels

def train_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((train_Q1, train_Q2, train_y))
    dataset = dataset.shuffle(buffer_size=len(train_Q1))
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.map(rearrange)
    dataset = dataset.repeat(EPOCH)
    iterator = dataset.make_one_shot_iterator()
    
    return iterator.get_next()

def eval_input_fn():
    dataset = tf.data.Dataset.from_tensor_slices((test_Q1, test_Q2, test_y))
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.map(rearrange)
    iterator = dataset.make_one_shot_iterator()
    
    return iterator.get_next()

# %% [markdown]
# # 모델

# %%
def Malstm(features, labels, mode):
        
    TRAIN = mode == tf.estimator.ModeKeys.TRAIN
    EVAL = mode == tf.estimator.ModeKeys.EVAL
    PREDICT = mode == tf.estimator.ModeKeys.PREDICT
            
    embedding = tf.keras.layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)
    
    base_embedded_matrix = embedding(features['base'])
    hypothesis_embedded_matrix = embedding(features['hypothesis'])
    
    # Question 1에 대한 LSTM모델
    q_lstm_fw_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units = 64, activation = tf.nn.tanh)
    q_lstm_bw_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units = 64, activation = tf.nn.tanh)
    _, q_output_states = tf.nn.bidirectional_dynamic_rnn(cell_fw = q_lstm_fw_cell,
                                                       cell_bw = q_lstm_bw_cell,
                                                       inputs = base_embedded_matrix,
                                                       dtype = tf.float32,
                                                      scope='query')
    # 마지막 state 값을 뽑아 추출한다
    q_final_state = tf.concat([q_output_states[0].h, q_output_states[1].h], axis=1)

    # Question 2 (유사한 쿼리)에 대한 LSTM모델
    s_lstm_fw_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units = 64, activation = tf.nn.tanh)
    s_lstm_bw_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units = 64, activation = tf.nn.tanh)
    _, s_output_states = tf.nn.bidirectional_dynamic_rnn(cell_fw = s_lstm_fw_cell,
                                                       cell_bw = s_lstm_bw_cell,
                                                       inputs = hypothesis_embedded_matrix,
                                                        dtype = tf.float32,
                                                      scope='sim_query')
    #LSTM의 마지막 state 값을 추출한다.
    sim_final_state = tf.concat([s_output_states[0].h, s_output_states[1].h], axis=1)
        
#     merged_matrix = tf.concat([base_sementic_matrix, hypothesis_sementic_matrix], -1)
#     logit_layer = tf.keras.layers.dot([base_sementic_matrix, hypothesis_sementic_matrix], axes=1, normalize=True)    

    with tf.variable_scope('output_layer'):
#     logit_layer = K.exp(-K.sum(K.abs(base_sementic_matrix - hypothesis_sementic_matrix), axis=1, keepdims=True))
        logit_layer = tf.exp(-tf.reduce_sum(tf.abs(q_final_state - sim_final_state), axis=1, keepdims=True))
        logit_layer = tf.squeeze(logit_layer, axis=-1)
                
    if PREDICT:
        return tf.estimator.EstimatorSpec(
                  mode=mode,
                  predictions={
                      'is_duplicate':logit_layer
                  })
    
    #prediction 진행 시, None
    if labels is not None:
        labels = tf.to_float(labels)
    
#     loss = tf.reduce_mean(tf.keras.metrics.binary_crossentropy(y_true=labels, y_pred=logit_layer))
    loss = tf.losses.mean_squared_error(labels=labels, predictions=logit_layer)
#     loss = tf.reduce_mean(tf.losses.sigmoid_cross_entropy(labels, logit_layer))
    
    if EVAL:
        accuracy = tf.metrics.accuracy(labels, tf.round(logit_layer))
        eval_metric_ops = {'acc': accuracy}
        return tf.estimator.EstimatorSpec(
                  mode=mode,
                  eval_metric_ops= eval_metric_ops,
                  loss=loss)

    elif TRAIN:

        global_step = tf.train.get_global_step()
        train_op = tf.train.AdamOptimizer(1e-3).minimize(loss, global_step)

        return tf.estimator.EstimatorSpec(
                  mode=mode,
                  train_op=train_op,
                  loss=loss)

# %% [markdown]
# # 학습

# %%
# os.environ["CUDA_VISIBLE_DEVICES"]="0" #For TEST  

model_dir = os.path.join(os.getcwd(), DATA_OUT_PATH + "/checkpoint/rnn/")
os.makedirs(model_dir, exist_ok=True)

config_tf = tf.estimator.RunConfig(save_checkpoints_steps=500,
                                save_checkpoints_secs=None,
                                  keep_checkpoint_max=2,
                                  log_step_count_steps=200)

lstm_est = tf.estimator.Estimator(Malstm, model_dir=model_dir, config=config_tf)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Python\\Python36\\venv\\kmu\\Scripts\\nlp\\Text_Similarlity\\./output//checkpoint/rnn/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 2, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 200, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002090B5232E8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
lstm_est.train(train_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-8-24fe79b3ad63>:13: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:loss = 0.5030184, step = 1
# INFO:tensorflow:global_step/sec: 5.89941
# INFO:tensorflow:loss = 0.2681255, step = 201 (33.899 sec)
# INFO:tensorflow:global_step/sec: 8.6311
# INFO:tensorflow:loss = 0.23085478, step = 401 (23.149 sec)
# INFO:tensorflow:Saving checkpoints for 500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.93101
# INFO:tensorflow:loss = 0.26855642, step = 601 (28.852 sec)
# INFO:tensorflow:global_step/sec: 8.38532
# INFO:tensorflow:loss = 0.2514676, step = 801 (23.853 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.65365
# INFO:tensorflow:loss = 0.18388014, step = 1001 (30.058 sec)
# INFO:tensorflow:global_step/sec: 8.63299
# INFO:tensorflow:loss = 0.19091456, step = 1201 (23.166 sec)
# INFO:tensorflow:global_step/sec: 8.29892
# INFO:tensorflow:loss = 0.16641447, step = 1401 (24.103 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.84136
# INFO:tensorflow:loss = 0.28509375, step = 1601 (29.231 sec)
# INFO:tensorflow:global_step/sec: 8.57648
# INFO:tensorflow:loss = 0.2010915, step = 1801 (23.320 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.24084
# INFO:tensorflow:loss = 0.21224254, step = 2001 (27.621 sec)
# INFO:tensorflow:global_step/sec: 8.49111
# INFO:tensorflow:loss = 0.26381242, step = 2201 (23.554 sec)
# INFO:tensorflow:global_step/sec: 8.68734
# INFO:tensorflow:loss = 0.15200132, step = 2401 (23.024 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.49048
# INFO:tensorflow:loss = 0.17837605, step = 2601 (26.698 sec)
# INFO:tensorflow:global_step/sec: 8.71816
# INFO:tensorflow:loss = 0.19014992, step = 2801 (22.940 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.59977
# INFO:tensorflow:loss = 0.1615689, step = 3001 (26.317 sec)
# INFO:tensorflow:global_step/sec: 8.73595
# INFO:tensorflow:loss = 0.17189386, step = 3201 (22.893 sec)
# INFO:tensorflow:global_step/sec: 8.79538
# INFO:tensorflow:loss = 0.19938779, step = 3401 (22.742 sec)
# INFO:tensorflow:Saving checkpoints for 3500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.60641
# INFO:tensorflow:loss = 0.14798978, step = 3601 (26.292 sec)
# INFO:tensorflow:global_step/sec: 8.80273
# INFO:tensorflow:loss = 0.19668293, step = 3801 (22.720 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.61999
# INFO:tensorflow:loss = 0.19866623, step = 4001 (26.247 sec)
# INFO:tensorflow:global_step/sec: 8.7326
# INFO:tensorflow:loss = 0.1863034, step = 4201 (22.902 sec)
# INFO:tensorflow:global_step/sec: 8.51388
# INFO:tensorflow:loss = 0.21308206, step = 4401 (23.494 sec)
# INFO:tensorflow:Saving checkpoints for 4500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.2377
# INFO:tensorflow:loss = 0.18288414, step = 4601 (27.631 sec)
# INFO:tensorflow:global_step/sec: 8.64242
# INFO:tensorflow:loss = 0.1593273, step = 4801 (23.142 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.70015
# INFO:tensorflow:loss = 0.24659467, step = 5001 (25.974 sec)
# INFO:tensorflow:global_step/sec: 8.7496
# INFO:tensorflow:loss = 0.27599797, step = 5201 (22.858 sec)
# INFO:tensorflow:global_step/sec: 8.09496
# INFO:tensorflow:loss = 0.16046135, step = 5401 (24.709 sec)
# INFO:tensorflow:Saving checkpoints for 5500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.2892
# INFO:tensorflow:loss = 0.15043758, step = 5601 (27.435 sec)
# INFO:tensorflow:global_step/sec: 8.78822
# INFO:tensorflow:loss = 0.15798844, step = 5801 (22.758 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.66491
# INFO:tensorflow:loss = 0.1493685, step = 6001 (26.092 sec)
# INFO:tensorflow:global_step/sec: 8.76582
# INFO:tensorflow:loss = 0.19751498, step = 6201 (22.816 sec)
# INFO:tensorflow:global_step/sec: 8.36772
# INFO:tensorflow:loss = 0.19343746, step = 6401 (23.904 sec)
# INFO:tensorflow:Saving checkpoints for 6500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.512
# INFO:tensorflow:loss = 0.1806125, step = 6601 (26.622 sec)
# INFO:tensorflow:global_step/sec: 8.76081
# INFO:tensorflow:loss = 0.16220923, step = 6801 (22.830 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.92857
# INFO:tensorflow:loss = 0.19210872, step = 7001 (28.866 sec)
# INFO:tensorflow:global_step/sec: 8.62637
# INFO:tensorflow:loss = 0.14863563, step = 7201 (23.183 sec)
# INFO:tensorflow:global_step/sec: 8.78666
# INFO:tensorflow:loss = 0.16929284, step = 7401 (22.771 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.62023
# INFO:tensorflow:loss = 0.17182878, step = 7601 (26.238 sec)
# INFO:tensorflow:global_step/sec: 8.6895
# INFO:tensorflow:loss = 0.22642544, step = 7801 (23.016 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.2138
# INFO:tensorflow:loss = 0.23320031, step = 8001 (27.724 sec)
# INFO:tensorflow:global_step/sec: 8.74553
# INFO:tensorflow:loss = 0.2099914, step = 8201 (22.870 sec)
# INFO:tensorflow:global_step/sec: 8.78115
# INFO:tensorflow:loss = 0.15251708, step = 8401 (22.778 sec)
# INFO:tensorflow:Saving checkpoints for 8500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.67246
# INFO:tensorflow:loss = 0.13147336, step = 8601 (26.065 sec)
# INFO:tensorflow:global_step/sec: 8.69697
# INFO:tensorflow:loss = 0.1465545, step = 8801 (22.996 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.45851
# INFO:tensorflow:loss = 0.13195994, step = 9001 (26.815 sec)
# INFO:tensorflow:global_step/sec: 8.61135
# INFO:tensorflow:loss = 0.18425772, step = 9201 (23.225 sec)
# INFO:tensorflow:global_step/sec: 8.61305
# INFO:tensorflow:loss = 0.13780224, step = 9401 (23.229 sec)
# INFO:tensorflow:Saving checkpoints for 9500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.38771
# INFO:tensorflow:loss = 0.18339112, step = 9601 (27.063 sec)
# INFO:tensorflow:global_step/sec: 8.72672
# INFO:tensorflow:loss = 0.12953924, step = 9801 (22.919 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.32517
# INFO:tensorflow:loss = 0.19235086, step = 10001 (27.303 sec)
# INFO:tensorflow:global_step/sec: 8.71088
# INFO:tensorflow:loss = 0.121314116, step = 10201 (22.960 sec)
# INFO:tensorflow:global_step/sec: 8.70047
# INFO:tensorflow:loss = 0.22056133, step = 10401 (22.990 sec)
# INFO:tensorflow:Saving checkpoints for 10500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.60396
# INFO:tensorflow:loss = 0.18044555, step = 10601 (26.299 sec)
# INFO:tensorflow:global_step/sec: 8.71929
# INFO:tensorflow:loss = 0.1911127, step = 10801 (22.937 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.68175
# INFO:tensorflow:loss = 0.23866054, step = 11001 (26.036 sec)
# INFO:tensorflow:global_step/sec: 7.88625
# INFO:tensorflow:loss = 0.17367047, step = 11201 (25.361 sec)
# INFO:tensorflow:global_step/sec: 8.57949
# INFO:tensorflow:loss = 0.1257307, step = 11401 (23.313 sec)
# INFO:tensorflow:Saving checkpoints for 11500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.51715
# INFO:tensorflow:loss = 0.1810956, step = 11601 (26.603 sec)
# INFO:tensorflow:global_step/sec: 8.64889
# INFO:tensorflow:loss = 0.17392561, step = 11801 (23.125 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.4781
# INFO:tensorflow:loss = 0.11801262, step = 12001 (26.744 sec)
# INFO:tensorflow:global_step/sec: 8.53117
# INFO:tensorflow:loss = 0.16010869, step = 12201 (23.444 sec)
# INFO:tensorflow:global_step/sec: 8.71812
# INFO:tensorflow:loss = 0.14327917, step = 12401 (22.943 sec)
# INFO:tensorflow:Saving checkpoints for 12500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.47264
# INFO:tensorflow:loss = 0.14363904, step = 12601 (26.761 sec)
# INFO:tensorflow:global_step/sec: 8.6266
# INFO:tensorflow:loss = 0.17641732, step = 12801 (23.184 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.54618
# INFO:tensorflow:loss = 0.18969065, step = 13001 (26.504 sec)
# INFO:tensorflow:global_step/sec: 8.67374
# INFO:tensorflow:loss = 0.28909296, step = 13201 (23.058 sec)
# INFO:tensorflow:global_step/sec: 8.42236
# INFO:tensorflow:loss = 0.13445798, step = 13401 (23.749 sec)
# INFO:tensorflow:Saving checkpoints for 13500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.44211
# INFO:tensorflow:loss = 0.13550176, step = 13601 (26.871 sec)
# INFO:tensorflow:global_step/sec: 8.67479
# INFO:tensorflow:loss = 0.120146185, step = 13801 (23.056 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.60092
# INFO:tensorflow:loss = 0.20527726, step = 14001 (26.312 sec)
# INFO:tensorflow:global_step/sec: 8.51963
# INFO:tensorflow:loss = 0.09795557, step = 14201 (23.475 sec)
# INFO:tensorflow:global_step/sec: 8.24375
# INFO:tensorflow:loss = 0.10516836, step = 14401 (24.265 sec)
# INFO:tensorflow:Saving checkpoints for 14500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.54168
# INFO:tensorflow:loss = 0.18957418, step = 14601 (26.515 sec)
# INFO:tensorflow:global_step/sec: 8.71861
# INFO:tensorflow:loss = 0.17614682, step = 14801 (22.939 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.50047
# INFO:tensorflow:loss = 0.27238154, step = 15001 (26.665 sec)
# INFO:tensorflow:global_step/sec: 8.64254
# INFO:tensorflow:loss = 0.15952796, step = 15201 (23.142 sec)
# INFO:tensorflow:global_step/sec: 8.76005
# INFO:tensorflow:loss = 0.08765131, step = 15401 (22.838 sec)
# INFO:tensorflow:Saving checkpoints for 15500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.62259
# INFO:tensorflow:loss = 0.21168762, step = 15601 (26.231 sec)
# INFO:tensorflow:global_step/sec: 8.71015
# INFO:tensorflow:loss = 0.18064064, step = 15801 (22.962 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.42285
# INFO:tensorflow:loss = 0.1637612, step = 16001 (26.943 sec)
# INFO:tensorflow:global_step/sec: 8.61105
# INFO:tensorflow:loss = 0.17587136, step = 16201 (23.226 sec)
# INFO:tensorflow:global_step/sec: 8.67476
# INFO:tensorflow:loss = 0.13117863, step = 16401 (23.057 sec)
# INFO:tensorflow:Saving checkpoints for 16500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.6168
# INFO:tensorflow:loss = 0.1582882, step = 16601 (26.255 sec)
# INFO:tensorflow:global_step/sec: 8.39626
# INFO:tensorflow:loss = 0.15556528, step = 16801 (23.820 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.32624
# INFO:tensorflow:loss = 0.14989823, step = 17001 (27.299 sec)
# INFO:tensorflow:global_step/sec: 8.55089
# INFO:tensorflow:loss = 0.12214351, step = 17201 (23.389 sec)
# INFO:tensorflow:global_step/sec: 8.581
# INFO:tensorflow:loss = 0.09899988, step = 17401 (23.310 sec)
# INFO:tensorflow:Saving checkpoints for 17500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.58912
# INFO:tensorflow:loss = 0.09866801, step = 17601 (26.352 sec)
# INFO:tensorflow:global_step/sec: 8.58204
# INFO:tensorflow:loss = 0.18584518, step = 17801 (23.305 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.36994
# INFO:tensorflow:loss = 0.12036855, step = 18001 (27.136 sec)
# INFO:tensorflow:global_step/sec: 8.56235
# INFO:tensorflow:loss = 0.09223883, step = 18201 (23.358 sec)
# INFO:tensorflow:global_step/sec: 8.61368
# INFO:tensorflow:loss = 0.19948718, step = 18401 (23.222 sec)
# INFO:tensorflow:Saving checkpoints for 18500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.55937
# INFO:tensorflow:loss = 0.14686926, step = 18601 (26.454 sec)
# INFO:tensorflow:global_step/sec: 8.54114
# INFO:tensorflow:loss = 0.1002847, step = 18801 (23.417 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.4916
# INFO:tensorflow:loss = 0.21449682, step = 19001 (26.697 sec)
# INFO:tensorflow:global_step/sec: 8.47671
# INFO:tensorflow:loss = 0.074551284, step = 19201 (23.594 sec)
# INFO:tensorflow:global_step/sec: 8.58388
# INFO:tensorflow:loss = 0.15663373, step = 19401 (23.303 sec)
# INFO:tensorflow:Saving checkpoints for 19500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.51377
# INFO:tensorflow:loss = 0.18955404, step = 19601 (26.614 sec)
# INFO:tensorflow:global_step/sec: 8.59
# INFO:tensorflow:loss = 0.117998675, step = 19801 (23.283 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.48997
# INFO:tensorflow:loss = 0.16629721, step = 20001 (26.702 sec)
# INFO:tensorflow:global_step/sec: 8.61627
# INFO:tensorflow:loss = 0.09363664, step = 20201 (23.212 sec)
# INFO:tensorflow:global_step/sec: 8.61095
# INFO:tensorflow:loss = 0.17112634, step = 20401 (23.229 sec)
# INFO:tensorflow:Saving checkpoints for 20500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.58603
# INFO:tensorflow:loss = 0.11421372, step = 20601 (26.363 sec)
# INFO:tensorflow:global_step/sec: 8.55933
# INFO:tensorflow:loss = 0.11906939, step = 20801 (23.366 sec)
# INFO:tensorflow:Saving checkpoints for 21000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.43163
# INFO:tensorflow:loss = 0.23069921, step = 21001 (26.912 sec)
# INFO:tensorflow:global_step/sec: 8.61233
# INFO:tensorflow:loss = 0.01756022, step = 21201 (23.222 sec)
# INFO:tensorflow:global_step/sec: 8.62429
# INFO:tensorflow:loss = 0.08249684, step = 21401 (23.193 sec)
# INFO:tensorflow:Saving checkpoints for 21500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.57222
# INFO:tensorflow:loss = 0.17276435, step = 21601 (26.410 sec)
# INFO:tensorflow:global_step/sec: 8.47426
# INFO:tensorflow:loss = 0.17549577, step = 21801 (23.602 sec)
# INFO:tensorflow:Saving checkpoints for 22000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.42003
# INFO:tensorflow:loss = 0.16395527, step = 22001 (26.954 sec)
# INFO:tensorflow:global_step/sec: 8.5986
# INFO:tensorflow:loss = 0.085505776, step = 22201 (23.260 sec)
# INFO:tensorflow:global_step/sec: 8.60636
# INFO:tensorflow:loss = 0.2176215, step = 22401 (23.241 sec)
# INFO:tensorflow:Saving checkpoints for 22500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.57502
# INFO:tensorflow:loss = 0.0922111, step = 22601 (26.400 sec)
# INFO:tensorflow:global_step/sec: 8.55106
# INFO:tensorflow:loss = 0.16220686, step = 22801 (23.389 sec)
# INFO:tensorflow:Saving checkpoints for 23000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.60192
# INFO:tensorflow:loss = 0.06577252, step = 23001 (26.310 sec)
# INFO:tensorflow:global_step/sec: 8.58712
# INFO:tensorflow:loss = 0.08466216, step = 23201 (23.290 sec)
# INFO:tensorflow:global_step/sec: 8.62071
# INFO:tensorflow:loss = 0.1445936, step = 23401 (23.203 sec)
# INFO:tensorflow:Saving checkpoints for 23500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.55254
# INFO:tensorflow:loss = 0.15000518, step = 23601 (26.479 sec)
# INFO:tensorflow:global_step/sec: 8.55379
# INFO:tensorflow:loss = 0.08786006, step = 23801 (23.381 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.55168
# INFO:tensorflow:loss = 0.15767172, step = 24001 (26.485 sec)
# INFO:tensorflow:global_step/sec: 8.21458
# INFO:tensorflow:loss = 0.16774645, step = 24201 (24.347 sec)
# INFO:tensorflow:global_step/sec: 8.62668
# INFO:tensorflow:loss = 0.14692469, step = 24401 (23.186 sec)
# INFO:tensorflow:Saving checkpoints for 24500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.50758
# INFO:tensorflow:loss = 0.15628424, step = 24601 (26.638 sec)
# INFO:tensorflow:global_step/sec: 8.55671
# INFO:tensorflow:loss = 0.09421028, step = 24801 (23.373 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.23684
# INFO:tensorflow:loss = 0.08897933, step = 25001 (27.635 sec)
# INFO:tensorflow:global_step/sec: 8.28773
# INFO:tensorflow:loss = 0.23685887, step = 25201 (24.132 sec)
# INFO:tensorflow:global_step/sec: 8.6359
# INFO:tensorflow:loss = 0.10550314, step = 25401 (23.162 sec)
# INFO:tensorflow:Saving checkpoints for 25500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.27323
# INFO:tensorflow:loss = 0.17493638, step = 25601 (27.496 sec)
# INFO:tensorflow:global_step/sec: 8.59817
# INFO:tensorflow:loss = 0.16824156, step = 25801 (23.260 sec)
# INFO:tensorflow:Saving checkpoints for 26000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.45895
# INFO:tensorflow:loss = 0.2403092, step = 26001 (26.814 sec)
# INFO:tensorflow:global_step/sec: 8.6008
# INFO:tensorflow:loss = 0.10814593, step = 26201 (23.253 sec)
# INFO:tensorflow:global_step/sec: 8.52177
# INFO:tensorflow:loss = 0.17793518, step = 26401 (23.472 sec)
# INFO:tensorflow:Saving checkpoints for 26500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.55368
# INFO:tensorflow:loss = 0.17015547, step = 26601 (26.474 sec)
# INFO:tensorflow:global_step/sec: 8.4791
# INFO:tensorflow:loss = 0.059263796, step = 26801 (23.587 sec)
# INFO:tensorflow:Saving checkpoints for 27000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.40234
# INFO:tensorflow:loss = 0.09312338, step = 27001 (27.020 sec)
# INFO:tensorflow:global_step/sec: 8.60038
# INFO:tensorflow:loss = 0.14558849, step = 27201 (23.254 sec)
# INFO:tensorflow:global_step/sec: 8.62145
# INFO:tensorflow:loss = 0.10269898, step = 27401 (23.201 sec)
# INFO:tensorflow:Saving checkpoints for 27500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.50056
# INFO:tensorflow:loss = 0.19352812, step = 27601 (26.662 sec)
# INFO:tensorflow:global_step/sec: 8.59338
# INFO:tensorflow:loss = 0.15127575, step = 27801 (23.273 sec)
# INFO:tensorflow:Saving checkpoints for 28000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.4139
# INFO:tensorflow:loss = 0.096889086, step = 28001 (26.977 sec)
# INFO:tensorflow:global_step/sec: 8.59731
# INFO:tensorflow:loss = 0.12756334, step = 28201 (23.263 sec)
# INFO:tensorflow:global_step/sec: 8.59424
# INFO:tensorflow:loss = 0.2634593, step = 28401 (23.275 sec)
# INFO:tensorflow:Saving checkpoints for 28500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.56108
# INFO:tensorflow:loss = 0.18866703, step = 28601 (26.447 sec)
# INFO:tensorflow:global_step/sec: 8.43854
# INFO:tensorflow:loss = 0.091771394, step = 28801 (23.701 sec)
# INFO:tensorflow:Saving checkpoints for 29000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.58224
# INFO:tensorflow:loss = 0.14323029, step = 29001 (26.378 sec)
# INFO:tensorflow:global_step/sec: 8.51095
# INFO:tensorflow:loss = 0.13660285, step = 29201 (23.499 sec)
# INFO:tensorflow:global_step/sec: 8.55869
# INFO:tensorflow:loss = 0.184031, step = 29401 (23.370 sec)
# INFO:tensorflow:Saving checkpoints for 29500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.37506
# INFO:tensorflow:loss = 0.13819368, step = 29601 (27.116 sec)
# INFO:tensorflow:global_step/sec: 8.61888
# INFO:tensorflow:loss = 0.088250935, step = 29801 (23.205 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.46144
# INFO:tensorflow:loss = 0.15029156, step = 30001 (26.804 sec)
# INFO:tensorflow:global_step/sec: 8.59124
# INFO:tensorflow:loss = 0.11502163, step = 30201 (23.280 sec)
# INFO:tensorflow:global_step/sec: 8.5919
# INFO:tensorflow:loss = 0.081227034, step = 30401 (23.278 sec)
# INFO:tensorflow:Saving checkpoints for 30500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.55624
# INFO:tensorflow:loss = 0.13224488, step = 30601 (26.468 sec)
# INFO:tensorflow:global_step/sec: 8.57573
# INFO:tensorflow:loss = 0.08951283, step = 30801 (23.322 sec)
# INFO:tensorflow:Saving checkpoints for 31000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.36232
# INFO:tensorflow:loss = 0.21951394, step = 31001 (27.164 sec)
# INFO:tensorflow:global_step/sec: 8.59007
# INFO:tensorflow:loss = 0.12414428, step = 31201 (23.284 sec)
# INFO:tensorflow:global_step/sec: 8.59992
# INFO:tensorflow:loss = 0.13856888, step = 31401 (23.259 sec)
# INFO:tensorflow:Saving checkpoints for 31500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.44164
# INFO:tensorflow:loss = 0.17612487, step = 31601 (26.873 sec)
# INFO:tensorflow:global_step/sec: 8.5037
# INFO:tensorflow:loss = 0.15918304, step = 31801 (23.520 sec)
# INFO:tensorflow:Saving checkpoints for 32000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.51572
# INFO:tensorflow:loss = 0.09775566, step = 32001 (26.610 sec)
# INFO:tensorflow:global_step/sec: 8.56852
# INFO:tensorflow:loss = 0.07971723, step = 32201 (23.342 sec)
# INFO:tensorflow:global_step/sec: 8.60102
# INFO:tensorflow:loss = 0.08015205, step = 32401 (23.257 sec)
# INFO:tensorflow:Saving checkpoints for 32500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 7.51182
# INFO:tensorflow:loss = 0.084236115, step = 32601 (26.621 sec)
# INFO:tensorflow:global_step/sec: 8.60348
# INFO:tensorflow:loss = 0.19508082, step = 32801 (23.246 sec)
# INFO:tensorflow:Saving checkpoints for 33000 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:global_step/sec: 6.61385
# INFO:tensorflow:loss = 0.06299941, step = 33001 (30.242 sec)
# INFO:tensorflow:global_step/sec: 8.54104
# INFO:tensorflow:loss = 0.14304492, step = 33201 (23.415 sec)
# INFO:tensorflow:global_step/sec: 8.59345
# INFO:tensorflow:loss = 0.11552608, step = 33401 (23.277 sec)
# INFO:tensorflow:Saving checkpoints for 33500 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 33586 into C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.122601e-07.

# %%
lstm_est.evaluate(eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-29-20:22:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt-33586
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-06-29-20:22:34
# INFO:tensorflow:Saving dict for global step 33586: acc = 0.787827, global_step = 33586, loss = 0.1491001
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 33586: C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt-33586
# {'acc': 0.787827, 'loss': 0.1491001, 'global_step': 33586}

# %% [markdown]
# # 테스트

# %%
TEST_Q1_DATA_FILE = 'test_q1.npy'
TEST_Q2_DATA_FILE = 'test_q2.npy'
TEST_ID_DATA_FILE = 'test_id.npy'

test_q1_data = np.load(open(DATA_IN_PATH + TEST_Q1_DATA_FILE, 'rb'))
test_q2_data = np.load(open(DATA_IN_PATH + TEST_Q2_DATA_FILE, 'rb'))
test_id_data = np.load(open(DATA_IN_PATH + TEST_ID_DATA_FILE, 'rb'))

# %%
predict_input_fn = tf.estimator.inputs.numpy_input_fn(x={"base":test_q1_data, 
                                                         "hypothesis":test_q2_data}, 
                                                      shuffle=False)
predictions = np.array([p['is_duplicate'] for p in lstm_est.predict(input_fn=predict_input_fn)])
# Out:
# WARNING:tensorflow:From c:\python\python36\venv\kmu\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\python\python36\venv\kmu\lib\site-packages\tensorflow\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Python\Python36\venv\kmu\Scripts\nlp\Text_Similarlity\./output//checkpoint/rnn/model.ckpt-33586
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\python\python36\venv\kmu\lib\site-packages\tensorflow\python\training\monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.

# %%
print(len(predictions)) #2345796

output = pd.DataFrame( data={"test_id":test_id_data, "is_duplicate": list(predictions)} )
output.to_csv( "./data/rnn_predict.csv", index=False, quoting=3 )
# Out:
# 2345796

# %% [markdown]
# ### 캐글에서 0.45025으로 2265등 정도 나온다
